# %% [markdown]
# # Report on Assignment 3 IML
# ## By Manas and Avi

# %% [markdown]
# ## Lets begin with the VLT model which I have worked on

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2  
import sklearn 
import pickle

# %%
# Display architecture image and some config details.
path = "/Users/manasvenkatasairavulapalli/Desktop/Computer Science stuff/Pure CS/Introduction to Machine Learning/Final Project/images/unnamed.jpg"
if os.path.exists(path):
    img = cv2.imread(path)
    if img is None:
        print(f"Failed to load image (cv2 returned None): {path}")
    else:
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(6,6))
        plt.imshow(img_rgb)
        plt.axis('off')
        plt.show()
else:
    print(f"Image not found: {path}")

print("config details here")
config = {
    "vocab_size": 8000,
    "embed_size": 512,
    "hidden_size": 512,
    "num_heads": 8,
    "num_layers": 4,
    "dropout": 0.2,
    "max_objects": 10,
    "batch_size": 64,
    "learning_rate": 0.0003,
    "epochs": 50,
    "patience": 5
}
print(config)
# Out:
#   Cell In[3], line 10
#     print("vocab_size": 8000,
#                       ^
# SyntaxError: invalid syntax
